# %%
from src.load import load_spotify_json
from src.transform import clean_streaming_data
from src.analysis import (
    top_artists,
    top_tracks,
    listening_by_year,
    top_artist_by_year,
)

df_raw = load_spotify_json("../data/raw")
df = clean_streaming_data(df_raw)

top_artists(df)
top_tracks(df)
listening_by_year(df)
top_artist_by_year(df)
